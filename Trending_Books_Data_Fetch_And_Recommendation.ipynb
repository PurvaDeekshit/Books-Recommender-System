# %%
#Get data from Google BOOKS API
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
import re 
from goodreads import client
import datetime
import time
import nltk
#nltk.download('stopwords')
import pickle
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import linear_kernel

# %%
#Read Google Books API Developer Key from key.txt file
DEVELOPER_KEY = ""
with open('googleapi_key.txt') as file:
    DEVELOPER_KEY = str(file.readline())

# %%
keywords=['current+trending+books','current+bestseller+books']
print(keywords)
# Out:
# ['current+trending+books', 'current+bestseller+books']

# %%
def get_volumeinfo(item):
    iteminfo = {}
    
    keys = ['title','subtitle','authors','publisher','publishedDate','description','industryIdentifiers','readingModes','pageCount','printType','categories','averageRating','ratingsCount','maturityRating','language','infoLink']
    
    for key in keys :
        try :
            if(item['volumeInfo'][key]) :
                iteminfo[key] = item['volumeInfo'][key]
        except:
            iteminfo[key] = None
    
    return iteminfo

# %%
def get_isbn(info):
    isbn = None
    try :
        identifiers = info['industryIdentifiers']
        for x in range(len(identifiers)):
            if(str(identifiers[x]['type']) == 'ISBN_13'):
                isbn = identifiers[x]['identifier']
    except:
        pass
    
    return isbn

# %%
pages_to_fetch = 20
trending_books = []

def fetch_data(url):
    for i in range(pages_to_fetch):
        start_index = i *40
        print("page num : ", start_index)
        params = {'maxResults':40,'startIndex':start_index}
        url_data = requests.get(url,params=params).json()
        try:
            for j in range(len(url_data['items'])):
                print("Processing for item : ", j)
                item_info = get_volumeinfo(url_data['items'][j])
                print("item info : ", item_info)
                isbn = get_isbn(item_info)
                if isbn:
                    item_info['isbn'] = isbn
                else:
                    item_info['isbn'] = None
                trending_books.append(item_info)
        except:
            pass

# %%
print("Start time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
for item in range(len(keywords)):
    fetch_item = keywords[item]
    print("Fetch : ", fetch_item )
    #Get single book
    url = 'https://www.googleapis.com/books/v1/volumes?q=' + str(fetch_item) + ' &key=' + str(DEVELOPER_KEY)
    print("url : ",url)
    fetch_data(url)
print("End time : ", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start time :  2019-08-09 02:04:36
# Fetch :  current+trending+books
# url :  https://www.googleapis.com/books/v1/volumes?q=current+trending+books &key=AIzaSyAn2_08aOmG_dXnOPy_Tumz_lt_PLg7u98
# page num :  0
# Processing for item :  0
# item info :  {'title': 'Big Data', 'subtitle': 'A Revolution That Will Transform How We Live, Work, and Think', 'authors': ['Viktor Mayer-Schönberger', 'Kenneth Cukier'], 'publisher': 'Houghton Mifflin Harcourt', 'publishedDate': '2013-03-05', 'description': 'A revelatory exploration of the hottest trend in technology and the dramatic impact it will have on the economy, science, and society at large. Which paint color is most likely to tell you that a used car is in good shape? How can officials identify the most dangerous New York City manholes before they explode? And how did Google searches predict the spread of the H1N1 flu outbreak? The key to answering these questions, and many more, is big data. “Big data” refers to our burgeoning ability to crunch vast collections of information, analyze it instantly, and draw sometimes profoundly surprising conclusions from it. This emerging science can translate myriad phenomena—from the price of airline tickets to the text of millions of books—into searchable form, and uses our increasing computing power to unearth epiphanies that we never could have seen before. A revolution on par with the Internet or perhaps even the printing press, big data will change the way we think about business, health, politics, education, and innovation in the years to come. It also poses fresh threats, from the inevitable end of privacy as we know it to the prospect of being penalized for things we haven’t even done yet, based on big data’s ability to predict our future behavior. In this brilliantly clear, often surprising work, two leading experts explain what big data is, how it will change our lives, and what we can do to protect ourselves from its hazards. Big Data is the first big book about the next big thing. www.big-data-book.com', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780544002937'}, {'type': 'ISBN_10', 'identifier': '0544002938'}], 'readingModes': {'text': True, 'image': True}, 'pageCount': 240, 'printType': 'BOOK', 'categories': ['Business & Economics'], 'averageRating': 3.0, 'ratingsCount': 8, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=HpHcGAkFEjkC&source=gbs_api'}
# Processing for item :  1
# item info :  {'title': 'Where the Crawdads Sing', 'subtitle': None, 'authors': ['Delia Owens'], 'publisher': 'Penguin', 'publishedDate': '2018-08-14', 'description': '#1 New York Times Bestseller A Reese Witherspoon x Hello Sunshine Book Club Pick "I can\'t even express how much I love this book! I didn\'t want this story to end!"--Reese Witherspoon "Painfully beautiful."--The New York Times Book Review "Perfect for fans of Barbara Kingsolver."--Bustle For years, rumors of the "Marsh Girl" have haunted Barkley Cove, a quiet town on the North Carolina coast. So in late 1969, when handsome Chase Andrews is found dead, the locals immediately suspect Kya Clark, the so-called Marsh Girl. But Kya is not what they say. Sensitive and intelligent, she has survived for years alone in the marsh that she calls home, finding friends in the gulls and lessons in the sand. Then the time comes when she yearns to be touched and loved. When two young men from town become intrigued by her wild beauty, Kya opens herself to a new life--until the unthinkable happens. Perfect for fans of Barbara Kingsolver and Karen Russell, Where the Crawdads Sing is at once an exquisite ode to the natural world, a heartbreaking coming-of-age story, and a surprising tale of possible murder. Owens reminds us that we are forever shaped by the children we once were, and that we are all subject to the beautiful and violent secrets that nature keeps.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780735219113'}, {'type': 'ISBN_10', 'identifier': '0735219117'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 384, 'printType': 'BOOK', 'categories': ['Fiction'], 'averageRating': 4.0, 'ratingsCount': 83, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=CGVDDwAAQBAJ&source=gbs_api'}
# Processing for item :  2
# item info :  {'title': 'Feeling Good', 'subtitle': 'The New Mood Therapy', 'authors': ['David D. Burns'], 'publisher': None, 'publishedDate': '1992', 'description': 'A guide to a drug-free cure for anxiety, guilt, pessimism, procrastination, and low self-esteem features information on negative feelings, mood swings, hostility, criticism, approval addiction, and more. Reprint.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0380718030'}, {'type': 'ISBN_13', 'identifier': '9780380718030'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 466, 'printType': 'BOOK', 'categories': ['Cognitive therapy.'], 'averageRating': 4.0, 'ratingsCount': 6, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'http://books.google.com/books?id=SXI4unwowIEC&dq=current+trending+books&hl=&source=gbs_api'}
# Processing for item :  3
# item info :  {'title': 'The Better Angels of Our Nature', 'subtitle': 'Why Violence Has Declined', 'authors': ['Steven Pinker'], 'publisher': 'Penguin Group USA', 'publishedDate': '2012-09', 'description': "Presents a controversial history of violence which argues that today's world is the most peaceful time in human existence, drawing on psychological insights into intrinsic values that are causing people to condemn violence as an acceptable measure.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780143122012'}, {'type': 'ISBN_10', 'identifier': '0143122010'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 802, 'printType': 'BOOK', 'categories': ['Psychology'], 'averageRating': 4.0, 'ratingsCount': 16, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'http://books.google.com/books?id=8-vYCwAAQBAJ&dq=current+trending+books&hl=&source=gbs_api'}
# Processing for item :  4
# item info :  {'title': 'Current Issues In Nursing - E-Book', 'subtitle': None, 'authors': ['Perle Slavik Cowen', 'Sue Moorhead'], 'publisher': 'Elsevier Health Sciences', 'publishedDate': '2014-04-14', 'description': "Current Issues in Nursing provides a forum for knowledgeable debate on the important issues that nurses face today. This resource provides the opportunity to analyze conflicting viewpoints and develop your own thoughts on demands being made for the nursing profession and the difficult issues affecting today's health care delivery. Continually praised for its in-depth discussion of critical issues, solid organization of material, and encouragement of independent thinking, you’ll find this text a valuable resource in the modern world of nursing. Offers comprehensive and timely coverage of the issues affecting nursing education and practice. UNIQUE! Over 100 well-known contributors offer their expert insights and analysis. UNIQUE! Viewpoint chapters present controversial issues to showcase pressing issues facing nursing today. New content covering the following topics: The Challenges of Nursing on an International Level Health Care Systems and Practice Ethics, Legal, and Social Issues The Changing Practice Professional Challenges, Collaboration, & Conflict Violence Prevention and Care: Nursing’s Role Definitions of Nursing Changing Education", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780323293198'}, {'type': 'ISBN_10', 'identifier': '0323293190'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': 832, 'printType': 'BOOK', 'categories': ['Medical'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=zu4LBAAAQBAJ&source=gbs_api'}
# Processing for item :  5
# item info :  {'title': 'Current Controversies in Perinatology, An Issue of Clinics in Perinatology,', 'subtitle': None, 'authors': ['Robert H. Lane'], 'publisher': 'Elsevier Health Sciences', 'publishedDate': '2014-11-20', 'description': 'Neonatal-perinatal medicine has a strong history of evidence based practice but unfortunately there remain many areas of uncertainty and unproven hypotheses and treatments that may harm our highly vulnerable patients. When new ideas are introduced into the labor and delivery room or the NICU we have to evaluate these procedures and therapies before they become accepted as standards of care. We need to learn from the past lessons of grey baby syndrome and chloramphenicol and of kernicterus and sulfonamide antibiotics where therapeutic good intentions actually did more harm than good and increased the mortality rate of premature babies in the NICU.This proposed edition addresses a broad range of current topics in perinatal neonatal practice. The AAP has just issued new guidelines for the approach to a neonate exposed to maternal genital herpes virus infection. The recommendations were not evidence based and are highly controversial as well as confusing. These topics are addressed in a scholarly and objective manner to both address the controversy and help the practitioner make informed decisions.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780323326735'}, {'type': 'ISBN_10', 'identifier': '0323326730'}], 'readingModes': {'text': True, 'image': True}, 'pageCount': 321, 'printType': 'BOOK', 'categories': ['Medical'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=MHSPBQAAQBAJ&source=gbs_api'}
# Processing for item :  6
# item info :  {'title': 'The Real Top 1000 Baby Names', 'subtitle': 'Combined Spellings, Real Meanings, Current Trends & Newly Rising Names', 'authors': ['Elisabeth Busch'], 'publisher': 'Independently Published', 'publishedDate': '2019-01-02', 'description': 'The Real Top 1000 Baby Names provides an in-depth analysis of the most popular names, based on the newest data available. With this book, the reader can explore the following: - The Top 1000 names, spellings combined and ranks adjusted. Did you know that when you combine all the spellings for Jackson, it is the #1 baby name in the United States, and Aidan is #2? In this book, you will find a 100% accurate Top 1000 list uncluttered by repeat entries.- Real, researched meanings for the Top 200 names, how names are related, common name roots, and an index of names arranged by meaning. See how Elijah, Elias, Eli, and Elliott are really forms of the same name.- A full breakdown of the top baby name trends of the past four decades, from the McNames and "aylees" of the 1980s and 1990s to the Aidan names of the past decade.- Charts and graphs illustrating the lifecycle of a name, helping you to understand why and how names become popular.- A selection of rare and unusual names, rapidly climbing names, and names that are falling out of fashion the fastest.- A comparison of the Top 200 of 1880 and 2017 to help put everything in historical context.- The Supergroups of the Top 200: discover the combined might of Grayson, Jason, Kayson, and Mason or Adeline, Adalynn, and Madeline.- A list of 200 newly trending names like Margot, Saylor, Harvey, and Ronan.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1793035830'}, {'type': 'ISBN_13', 'identifier': '9781793035837'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 250, 'printType': 'BOOK', 'categories': None, 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'http://books.google.com/books?id=GXKTwAEACAAJ&dq=current+trending+books&hl=&source=gbs_api'}
# Processing for item :  7
# item info :  {'title': 'New Trends in Computational Collective Intelligence', 'subtitle': None, 'authors': ['David Camacho', 'Sang-Wook Kim', 'Bogdan Trawiński'], 'publisher': 'Springer', 'publishedDate': '2014-09-10', 'description': 'This book consists of 20 chapters in which the authors deal with different theoretical and practical aspects of new trends in Collective Computational Intelligence techniques. Computational Collective Intelligence methods and algorithms are one the current trending research topics from areas related to Artificial Intelligence, Soft Computing or Data Mining among others. Computational Collective Intelligence is a rapidly growing field that is most often understood as an AI sub-field dealing with soft computing methods which enable making group decisions and processing knowledge among autonomous units acting in distributed environments. Web-based Systems, Social Networks, and Multi-Agent Systems very often need these tools for working out consistent knowledge states, resolving conflicts and making decisions. The chapters included in this volume cover a selection of topics and new trends in several domains related to Collective Computational Intelligence: Language and Knowledge Processing, Data Mining Methods and Applications, Computer Vision, and Intelligent Computational Methods. This book will be useful for graduate and PhD students in computer science as well as for mature academics, researchers and practitioners interested in the methods and applications of collective computational intelligence in order to create new intelligent systems.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '
'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780698408326'}, {'type': 'ISBN_10', 'identifier': '0698408322'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 480, 'printType': 'BOOK', 'categories': ['Fiction'], 'averageRating': 3.5, 'ratingsCount': 6, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=MOFwDwAAQBAJ&source=gbs_api'}
# Processing for item :  10
# item info :  {'title': 'Fashion Forward', 'subtitle': 'A Guide to Fashion Forecasting', 'authors': ['Chelsea Rousso', 'Nancy Kaplan Ostroff'], 'publisher': 'Bloomsbury Publishing USA', 'publishedDate': '2018-02-22', 'description': "Fashion Forward demystifies the exciting career of a fashion forecaster and fosters skills that will benefit any design professional. The book begins with an overview of fashion forecasting theories and concepts and then leads readers through a step-by-step guide to creating and presenting a forecast. The authors reveal the inner workings of global fashion forecasting through real-world examples and interviews with both influential forecasters and the designers who rely upon them. Fashion Forward enables readers to start spotting tomorrow's trends today and compellingly communicate them-both visually and verbally-to inspire fashion innovators. New to this Edition - Current images and examples. Updated fashion photos to include current and trending images, professional presentations and forecast examples, plus new interviews and quotes. - Covers the latest methods and technology. New coverage of social media, technology and data analytics practices in fashion forecasting. - Enhanced global perspective. New content addressed the global apparel industry, emphasizes international forecasting firms, includes interviews with global forecaster and trend specialists, and more diverse images and examples throughout the book. - Practical career information and hands-on application. Updated and expanded career opportunities sections and enhanced activities provide real-world simulations and insights. - New online STUDIO resources offer students self-study quizzes, flashcards, additional projects and online resources. PLEASE NOTE: Purchasing or renting this ISBN does not include access to the STUDIO resources that accompany this text. To receive free access to the STUDIO content with new copies of this book, please refer to the book + STUDIO access card bundle ISBN 9781501328350.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781501328275'}, {'type': 'ISBN_10', 'identifier': '1501328271'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': 232, 'printType': 'BOOK', 'categories': ['Business & Economics'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'http://books.google.com/books?id=qg9BDwAAQBAJ&dq=current+trending+books&hl=&source=gbs_api'}
# Processing for item :  11
# item info :  {'title': 'The Hedge Funds Book', 'subtitle': 'How to Invest in Hedge Funds & Earn High Rates of Returns Safely', 'authors': ['Alan Northcott'], 'publisher': 'Atlantic Publishing Company', 'publishedDate': '2010', 'description': "Money managers have traditionally used hedge funds as they would mutual funds: to pool investors' money and place it in financial instruments in an effort to make a high positive return. Hedge funds have typically been available only to the very affluent or to investors with inside contacts, but today that has changed. Almost any investor can now participate in a hedge fund and earn high returns. Why should you consider investing in a hedge fund? One reason is simply the high potential returns. Since January 1990, as measured by the HFRI Fund Weighted Composite Index, which accounts for more than 1,600 funds listed on the internal Hedge Fund Research (HFR) Database, hedge funds have returned 14 percent per year through October 2005. Many funds have earned triple digit returns. As with many other business segments, the Internet and technology have opened up this attractive marketplace to a new breed of individual investors and speculators working part-time. You and I are now on an even playing field with the largest banks, wealthiest individuals, and trading institutions from the comfort of our own homes. Hedge funds can provide you with very high, secure rate of return 12%, 18%, 24%, or even 300% per year. If performed correctly, hedge fund trading will far outpace all other investments. This all sounds great, but what is the catch? There really is none, except you must know what you are doing! The key is learning how to proceed. This groundbreaking and exhaustively researched new book will provide everything you need to know to get you started generating high-investment returns with low risk from start to finish. In this easy to read and comprehensive new book, you will find out how to invest in hedge funds, evaluate their performance, and employ investing strategies and tactics, deftly using the latest technology to set up your account online. You will be able to handle fees, taxes, and risks, and you will get little known data to help you double or even triple your investment all while avoiding the common traps and pitfalls. In addition, we took the extra effort and spent an unprecedented amount of time researching, interviewing, e-mailing, and communicating with hundreds of today s most successful hedge fund investors. Aside from learning the basics of hedge fund trading, you will be privy to investors closed club secrets and proven successful ideas. Instruction is great, but advice from experts is even better, and the experts chronicled in this book are earning millions. If you are interested in learning essentially everything there is to know about hedge fund investing along with hundreds of hints, tips, strategies, and inside advice, then this book is for you.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781601380005'}, {'type': 'ISBN_10', 'identifier': '1601380003'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 288, 'printType': 'BOOK', 'categories': ['Business & Economics'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=YjDDisYijrwC&source=gbs_api'}
# Processing for item :  12
# item info :  {'title': 'Exit West', 'subtitle': 'A Novel', 'authors': ['Mohsin Hamid'], 'publisher': 'Penguin', 'publishedDate': '2017', 'description': 'In a country teetering on the brink of civil war, two young people meet -- sensual, fiercely independent Nadia and gentle, restrained Saeed. They embark on a furtive love affair, and are soon cloistered in a premature intimacy by the unrest roiling their city. When it explodes, turning familiar streets into a patchwork of checkpoints and bomb blasts, they begin to hear whispers about doors -- doors that can whisk people far away, if perilously and for a price. As the violence escalates, Nadia and Saeed decide that they no longer have a choice. Leaving their homeland and their old lives behind, they find a door and step through. Exit West follows the couple as they emerge into an alien and uncertain future, struggling to hold on to each other, to their past, to the very sense of who they are.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780735212176'}, {'type': 'ISBN_10', 'identifier': '0735212171'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 231, 'printType': 'BOOK', 'categories': ['Fiction'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'http://books.google.com/books?id=fUAdDgAAQBAJ&dq=current+trending+books&hl=&source=gbs_api'}
# Processing for item :  13
# item info :  {'title': 'The WEALTHTECH Book', 'subtitle': 'The FinTech Handbook for Investors, Entrepreneurs and Finance Visionaries', 'authors': ['Susanne Chishti', 'Thomas Puschmann'], 'publisher': 'John Wiley & Sons', 'publishedDate': '2018-04-19', 'description': 'Get a handle on disruption, innovation and opportunity in investment technology The digital evolution is enabling the creation of sophisticated software solutions that make money management more accessible, affordable and eponymous. Full automation is attractive to investors at an early stage of wealth accumulation, but hybrid models are of interest to investors who control larger amounts of wealth, particularly those who have enough wealth to be able to efficiently diversify their holdings. Investors can now outperform their benchmarks more easily using the latest tech tools. The WEALTHTECH Book is the only comprehensive guide of its kind to the disruption, innovation and opportunity in technology in the investment management sector. It is an invaluable source of information for entrepreneurs, innovators, investors, insurers, analysts and consultants working in or interested in investing in this space. • Explains how the wealth management sector is being affected by competition from low-cost robo-advisors • Explores technology and start-up company disruption and how to delight customers while managing their assets • Explains how to achieve better returns using the latest fintech innovation • Includes inspirational success stories and new business models • Details overall market dynamics The WealthTech Book is essential reading for investment and fund managers, asset allocators, family offices, hedge, venture capital and private equity funds and entrepreneurs and start-ups.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '
'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781491723586'}, {'type': 'ISBN_10', 'identifier': '1491723580'}], 'readingModes': {'text': True, 'image': True}, 'pageCount': 88, 'printType': 'BOOK', 'categories': ['Poetry'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=D0HPAgAAQBAJ&source=gbs_api'}
# Processing for item :  16
# item info :  {'title': 'The World Until Yesterday', 'subtitle': 'What Can We Learn from Traditional Societies?', 'authors': ['Jared Diamond'], 'publisher': 'Penguin UK', 'publishedDate': '2013-01-10', 'description': "From the author of No.1 international bestseller Collapse, a mesmerizing portrait of the human past that offers profound lessons for how we can live today Visionary, prize-winning author Jared Diamond changed the way we think about the rise and fall of human civilizations with his previous international bestsellers Guns, Germs and Steel and Collapse. Now he returns with another epic - and groundbreaking - journey into our rapidly receding past. In The World Until Yesterday, Diamond reveals how traditional societies around the world offer an extraordinary window onto how our ancestors lived for the majority of human history - until virtually yesterday, in evolutionary terms - and provide unique, often overlooked insights into human nature. Drawing extensively on his decades working in the jungles of Papua New Guinea, Diamond explores how tribal societies approach essential human problems, from childrearing to conflict resolution to health, and discovers we have much to learn from traditional ways of life. He unearths remarkable findings - from the reason why modern afflictions like diabetes, obesity and Alzheimer's are virtually non-existent in tribal societies to the surprising benefits of multilingualism. Panoramic in scope and thrillingly original, The World Until Yesterday provides an enthralling first-hand picture of the human past that also suggests profound lessons for how to live well today. Jared Diamond is the Pulitzer Prize-winning author of the seminal million-copy-bestseller Guns, Germs, and Steel, which was named one of TIME's best non-fiction books of all time, and Collapse, a #1 international bestseller. A professor of geography at UCLA and noted polymath, Diamond's work has been influential in the fields of anthropology, biology, ornithology, ecology and history, among others.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781846148156'}, {'type': 'ISBN_10', 'identifier': '1846148154'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 512, 'printType': 'BOOK', 'categories': ['Social Science'], 'averageRating': 3.5, 'ratingsCount': 15, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'http://books.google.com/books?id=nech105NsugC&dq=current+trending+books&hl=&source=gbs_api'}
# Processing for item :  17
# item info :  {'title': 'The Nickel Boys', 'subtitle': 'A Novel', 'authors': ['Colson Whitehead'], 'publisher': 'Doubleday', 'publishedDate': '2019-07-16', 'description': 'In this bravura follow-up to the Pulitzer Prize, and National Book Award-winning #1 New York Times bestseller The Underground Railroad, Colson Whitehead brilliantly dramatizes another strand of American history through the story of two boys sentenced to a hellish reform school in Jim Crow-era Florida. As the Civil Rights movement begins to reach the black enclave of Frenchtown in segregated Tallahassee, Elwood Curtis takes the words of Dr. Martin Luther King
'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781451642292'}, {'type': 'ISBN_10', 'identifier': '1451642296'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 320, 'printType': 'BOOK', 'categories': ['History'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'MATURE', 'language': 'en', 'infoLink': 'http://books ...
# Processing for item :  22
# ...
# Processing for item :  22
# item info :  {'title': 'Silent Swans 3', 'subtitle': None, 'authors': ['Sherrilyn Kenyon'], 'publisher': 'Hachette UK', 'publishedDate': '2020-04-02', 'description': None, 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780349418650'}, {'type': 'ISBN_10', 'identifier': '0349418659'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 304, 'printType': 'BOOK', 'categories': ['Fiction'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'http://books.google.com/books?id=gU2lDwAAQBAJ&dq=current+bestseller+books&hl=&source=gbs_api'}
# Processing for item :  23
# item info :  {'title': 'A Life Unleashed', 'subtitle': 'Giving Birth to Your Dreams', 'authors': ['Christine Caine'], 'publisher': None, 'publishedDate': '2004', 'description': None, 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0980518733'}, {'type': 'ISBN_13', 'identifier': '9780980518733'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 219, 'printType': 'BOOK', 'categories': ['Christian life'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'http://books.google.com/books?id=VoWtmgEACAAJ&dq=current+bestseller+books&hl=&source=gbs_api'}
# Processing for item :  24
# item info :  {'title': 'The Atlantic Monthly', 'subtitle': None, 'authors': None, 'publisher': None, 'publishedDate': '1914', 'description': None, 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'UCSC:32106005791394'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': None, 'printType': 'BOOK', 'categories': ['Current events'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=VI8GAQAAIAAJ&source=gbs_api'}
# Processing for item :  25
# item info :  {'title': 'A Short History of Progress', 'subtitle': None, 'authors': ['Ronald Wright'], 'publisher': None, 'publishedDate': '2005', 'description': 'The twentieth century was a time of runaway growth in human population, consumption and technology, all of which placed tremendous demands on earth, air and water, the very elements of life. The urgent question of the twenty-first century is how, or whether, this can continue. The author explains our current predicament in the perspective of 10,000 years of history.', 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'OCLC:939679188'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': None, 'printType': 'BOOK', 'categories': ['Civilization'], 'averageRating': 5.0, 'ratingsCount': 1, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'http://books.google.com/books?id=l5epxgEACAAJ&dq=current+bestseller+books&hl=&source=gbs_api'}
# Processing for item :  26
# item info :  {'title': 'The Christian Advocate', 'subtitle': None, 'authors': None, 'publisher': None, 'publishedDate': '1922', 'description': None, 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'CORNELL:31924076347107'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': None, 'printType': 'BOOK', 'categories': ['Methodist Church'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=o7M6AQAAMAAJ&source=gbs_api'}
# Processing for item :  29
# item info :  {'title': 'The Outlook', 'subtitle': 'A Weekly Review of Politics, Art, Literature and Finance', 'authors': None, 'publisher': None, 'publishedDate': '1900', 'description': None, 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'MINN:31951P00540295B'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': None, 'printType': 'BOOK', 'categories': None, 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=jbccAQAAMAAJ&source=gbs_api'}
# Processing for item :  30
# item info :  {'title': "The Pianolist's Library of Music Rolls", 'subtitle': None, 'authors': ['Gustav Kobbé'], 'publisher': None, 'publishedDate': '1916', 'description': None, 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'NYPL:33433082269873'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': 58, 'printType': 'BOOK', 'categories': ['Player piano rolls'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=YyguAAAAYAAJ&source=gbs_api'}
# Processing for item :  31
# item info :  {'title': 'Opportunity', 'subtitle': None, 'authors': None, 'publisher': None, 'publishedDate': '1947', 'description': None, 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'UOM:39015032049234'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': None, 'printType': 'BOOK', 'categories': ['African Americans'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=9aIqAAAAMAAJ&source=gbs_api'}
# Processing for item :  32
# item info :  {'title': 'Vanity Fair', 'subtitle': None, 'authors': None, 'publisher': None, 'publishedDate': '1934', 'description': None, 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'STANFORD:36105005564914'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': None, 'printType': 'BOOK', 'categories': None, 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=C4A7AQAAIAAJ&source=gbs_api'}
# Processing for item :  33
# item info :  {'title': 'Scientific American', 'subtitle': None, 'authors': None, 'publisher': None, 'publishedDate': '1893', 'description': None, 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'STANFORD:36105012020728'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': None, 'printType': 'BOOK', 'categories': ['Science'], 'averageRating': 1.0, 'ratingsCount': 1, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=L4Y9AQAAIAAJ&source=gbs_api'}
# Processing for item :  34
# item info :  {'title': 'Christian Register', 'subtitle': None, 'authors': None, 'publisher': None, 'publishedDate': '1919', 'description': None, 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'CORNELL:31924069723173'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': None, 'printType': 'BOOK', 'categories': None, 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=-s8_AQAAMAAJ&source=gbs_api'}
# Processing for item :  35
# item info :  {'title': 'The Rural New-Yorker', 'subtitle': None, 'authors': None, 'publisher': None, 'publishedDate': '1905', 'description': None, 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'UIUC:30112072702498'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': None, 'printType': 'BOOK', 'categories': ['Agriculture'], 'averageRating': None, 'ratingsCount': None, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'https://play.google.com/store/books/details?id=3gdHAQAAMAAJ&source=gbs_api'}
# Processing for item :  36
# item info :  {'title': 'Balloons Can Be Murder', 'subtitle': 'The Ninth Charlie Parker Mystery', 'authors': ['Connie Shelton'], 'publisher': 'CreateSpace', 'publishedDate': '2010-07-19', 'description': 'Rachael Fairfield is a balloon pilot out to set a world altitude record during the upcoming Albuquerque International Balloon Fiesta. She\'s received several threats, though, and wants to hire Charlie and Ron to keep the stalker away from her. It shouldn\'t be a problem, says Rachael, because she knows who is sending the notes-her own father. Her testimony sent him to prison years ago and now he\'s out. They agree to take the case, but Charlie begins to suspect that it\'s not such a simple assignment. Praise for the Charlie Parker mysteries: "Fans of Southwestern mysteries will find that Shelton\'s engaging story, likable heroine, and comfortable prose make this a good choice." - Library Journal "Charlie is a good detective and a pleasant companion to unravel a mystery with." -- Mystery News "Shelton continues to combine suspenseful storytelling with sensitive portrayals of complex family relationships." --Booklist', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1453692258'}, {'type': 'ISBN_13', 'identifier': '9781453692257'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 280, 'printType': 'BOOK', 'categories': ['Fiction'], 'averageRating': 3.0, 'ratingsCount': 1, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'http://books.google.com/books?id=l1a8bwAACAAJ&dq=current+bestseller+books&hl=&source=gbs_api'}
# page num :  600
# Processing for item :  0
# item info :  {'title': 'Balloons Can Be Murder', 'subtitle': 'The Ninth Charlie Parker Mystery', 'authors': ['Connie Shelton'], 'publisher': 'CreateSpace', 'publishedDate': '2010-07-19', 'description': 'Rachael Fairfield is a balloon pilot out to set a world altitude record during the upcoming Albuquerque International Balloon Fiesta. She\'s received several threats, though, and wants to hire Charlie and Ron to keep the stalker away from her. It shouldn\'t be a problem, says Rachael, because she knows who is sending the notes-her own father. Her testimony sent him to prison years ago and now he\'s out. They agree to take the case, but Charlie begins to suspect that it\'s not such a simple assignment. Praise for the Charlie Parker mysteries: "Fans of Southwestern mysteries will find that Shelton\'s engaging story, likable heroine, and comfortable prose make this a good choice." - Library Journal "Charlie is a good detective and a pleasant companion to unravel a mystery with." -- Mystery News "Shelton continues to combine suspenseful storytelling with sensitive portrayals of complex family relationships." --Booklist', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1453692258'}, {'type': 'ISBN_13', 'identifier': '9781453692257'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 280, 'printType': 'BOOK', 'categories': ['Fiction'], 'averageRating': 3.0, 'ratingsCount': 1, 'maturityRating': 'NOT_MATURE', 'language': 'en', 'infoLink': 'http://books.google.com/books?id=l1a8bwAACAAJ&dq=current+bestseller+books&hl=&source=gbs_api'}
# page num :  640
# page num :  680
# page num :  720
# page num :  760
# End time :  2019-08-09 02:05:57

# %%
trending_books_data = pd.DataFrame.from_dict(trending_books,orient='columns')

# %%
trending_books_data.shape
# Out:
# (1197, 17)

# %%
trending_books_data.head(5)
# Out:
#                                       authors  averageRating  \
# 0  [Viktor Mayer-Schönberger, Kenneth Cukier]            3.0
# 1                               [Delia Owens]            4.0
# 2                            [David D. Burns]            4.0
# 3                             [Steven Pinker]            4.0
# 4          [Perle Slavik Cowen, Sue Moorhead]            NaN
#
#                categories                                        description  \
# 0  [Business & Economics]  A revelatory exploration of the hottest trend ...
# 1               [Fiction]  #1 New York Times Bestseller A Reese Witherspo...
# 2    [Cognitive therapy.]  A guide to a drug-free cure for anxiety, guilt...
# 3            [Psychology]  Presents a controversial history of violence w...
# 4               [Medical]  Current Issues in Nursing provides a forum for...
#
#                                  industryIdentifiers  \
# 0  [{'type': 'ISBN_13', 'identifier': '9780544002...
# 1  [{'type': 'ISBN_13', 'identifier': '9780735219...
# 2  [{'type': 'ISBN_10', 'identifier': '0380718030...
# 3  [{'type': 'ISBN_13', 'identifier': '9780143122...
# 4  [{'type': 'ISBN_13', 'identifier': '9780323293...
#
#                                             infoLink           isbn language  \
# 0  https://play.google.com/store/books/details?id...  9780544002937       en
# 1  https://play.google.com/store/books/details?id...  9780735219113       en
# 2  http://books.google.com/books?id=SXI4unwowIEC&...  9780380718030       en
# 3  http://books.google.com/books?id=8-vYCwAAQBAJ&...  9780143122012       en
# 4  https://play.google.com/store/books/details?id...  9780323293198       en
#
#   maturityRating  pageCount printType publishedDate  \
# 0     NOT_MATURE      240.0      BOOK    2013-03-05
# 1     NOT_MATURE      384.0      BOOK    2018-08-14
# 2     NOT_MATURE      466.0      BOOK          1992
# 3     NOT_MATURE      802.0      BOOK       2012-09
# 4     NOT_MATURE      832.0      BOOK    2014-04-14
#
#                    publisher  ratingsCount                     readingModes  \
# 0  Houghton Mifflin Harcourt           8.0    {'text': True, 'image': True}
# 1                    Penguin          83.0   {'text': True, 'image': False}
# 2                       None           6.0  {'text': False, 'image': False}
# 3          Penguin Group USA          16.0  {'text': False, 'image': False}
# 4   Elsevier Health Sciences           NaN   {'text': False, 'image': True}
#
#                                             subtitle  \
# 0  A Revolution That Will Transform How We Live, ...
# 1                                               None
# 2                               The New Mood Therapy
# 3                          Why Violence Has Declined
# 4                                               None
#
#                                 title
# 0                            Big Data
# 1             Where the Crawdads Sing
# 2                        Feeling Good
# 3     The Better Angels of Our Nature
# 4  Current Issues In Nursing - E-Book

# %%
#Keep only selected columns
columns_to_drop = ['averageRating','industryIdentifiers','infoLink','maturityRating','pageCount','printType','publishedDate','ratingsCount','readingModes','subtitle']
trending_books_data.drop(columns=columns_to_drop,inplace=True)

# %%
trending_books_data.shape
# Out:
# (1197, 7)

# %%
trending_books_data.head(10)
# Out:
#                                             authors  \
# 0        [Viktor Mayer-Schönberger, Kenneth Cukier]
# 1                                     [Delia Owens]
# 2                                  [David D. Burns]
# 3                                   [Steven Pinker]
# 4                [Perle Slavik Cowen, Sue Moorhead]
# 5                                  [Robert H. Lane]
# 6                                 [Elisabeth Busch]
# 7  [David Camacho, Sang-Wook Kim, Bogdan Trawiński]
# 8                  [Sheryl Sandberg, Adam M. Grant]
# 9                               [Elizabeth Gilbert]
#
#                     categories  \
# 0       [Business & Economics]
# 1                    [Fiction]
# 2         [Cognitive therapy.]
# 3                 [Psychology]
# 4                    [Medical]
# 5                    [Medical]
# 6                         None
# 7                  [Computers]
# 8  [Biography & Autobiography]
# 9                    [Fiction]
#
#                                          description           isbn language  \
# 0  A revelatory exploration of the hottest trend ...  9780544002937       en
# 1  #1 New York Times Bestseller A Reese Witherspo...  9780735219113       en
# 2  A guide to a drug-free cure for anxiety, guilt...  9780380718030       en
# 3  Presents a controversial history of violence w...  9780143122012       en
# 4  Current Issues in Nursing provides a forum for...  9780323293198       en
# 5  Neonatal-perinatal medicine has a strong histo...  9780323326735       en
# 6  The Real Top 1000 Baby Names provides an in-de...  9781793035837       en
# 7  This book consists of 20 chapters in which the...  9783319107745       en
# 8  "The author's experience with grief after the ...  9781524732684       en
# 9  From the # 1 New York Times bestselling author...  9780698408326       en
#
#                    publisher  \
# 0  Houghton Mifflin Harcourt
# 1                    Penguin
# 2                       None
# 3          Penguin Group USA
# 4   Elsevier Health Sciences
# 5   Elsevier Health Sciences
# 6    Independently Published
# 7                   Springer
# 8                      Knopf
# 9                    Penguin
#
#                                                title
# 0                                           Big Data
# 1                            Where the Crawdads Sing
# 2                                       Feeling Good
# 3                    The Better Angels of Our Nature
# 4                 Current Issues In Nursing - E-Book
# 5  Current Controversies in Perinatology, An Issu...
# 6                       The Real Top 1000 Baby Names
# 7  New Trends in Computational Collective Intelli...
# 8                                           Option B
# 9                                      City of Girls

# %%
trending_books_data.isnull().sum()
# Out:
# authors        215
# categories     136
# description    277
# isbn           337
# language         0
# publisher      324
# title            0
# dtype: int64

# %%
trending_books_data.dropna(inplace=True)

# %%
trending_books_data.head(10)
# Out:
#                                              authors  \
# 0         [Viktor Mayer-Schönberger, Kenneth Cukier]
# 1                                      [Delia Owens]
# 3                                    [Steven Pinker]
# 4                 [Perle Slavik Cowen, Sue Moorhead]
# 5                                   [Robert H. Lane]
# 7   [David Camacho, Sang-Wook Kim, Bogdan Trawiński]
# 8                   [Sheryl Sandberg, Adam M. Grant]
# 9                                [Elizabeth Gilbert]
# 10            [Chelsea Rousso, Nancy Kaplan Ostroff]
# 11                                  [Alan Northcott]
#
#                      categories  \
# 0        [Business & Economics]
# 1                     [Fiction]
# 3                  [Psychology]
# 4                     [Medical]
# 5                     [Medical]
# 7                   [Computers]
# 8   [Biography & Autobiography]
# 9                     [Fiction]
# 10       [Business & Economics]
# 11       [Business & Economics]
#
#                                           description           isbn language  \
# 0   A revelatory exploration of the hottest trend ...  9780544002937       en
# 1   #1 New York Times Bestseller A Reese Witherspo...  9780735219113       en
# 3   Presents a controversial history of violence w...  9780143122012       en
# 4   Current Issues in Nursing provides a forum for...  9780323293198       en
# 5   Neonatal-perinatal medicine has a strong histo...  9780323326735       en
# 7   This book consists of 20 chapters in which the...  9783319107745       en
# 8   "The author's experience with grief after the ...  9781524732684       en
# 9   From the # 1 New York Times bestselling author...  9780698408326       en
# 10  Fashion Forward demystifies the exciting caree...  9781501328275       en
# 11  Money managers have traditionally used hedge f...  9781601380005       en
#
#                       publisher  \
# 0     Houghton Mifflin Harcourt
# 1                       Penguin
# 3             Penguin Group USA
# 4      Elsevier Health Sciences
# 5      Elsevier Health Sciences
# 7                      Springer
# 8                         Knopf
# 9                       Penguin
# 10    Bloomsbury Publishing USA
# 11  Atlantic Publishing Company
#
#                                                 title
# 0                                            Big Data
# 1                             Where the Crawdads Sing
# 3                     The Better Angels of Our Nature
# 4                  Current Issues In Nursing - E-Book
# 5   Current Controversies in Perinatology, An Issu...
# 7   New Trends in Computational Collective Intelli...
# 8                                            Option B
# 9                                       City of Girls
# 10                                    Fashion Forward
# 11                               The Hedge Funds Book

# %%
trending_books_data['authors'] = trending_books_data['authors'].apply(', '.join)

# %%
trending_books_data.head(10)
# Out:
#                                            authors  \
# 0         Viktor Mayer-Schönberger, Kenneth Cukier
# 1                                      Delia Owens
# 3                                    Steven Pinker
# 4                 Perle Slavik Cowen, Sue Moorhead
# 5                                   Robert H. Lane
# 7   David Camacho, Sang-Wook Kim, Bogdan Trawiński
# 8                   Sheryl Sandberg, Adam M. Grant
# 9                                Elizabeth Gilbert
# 10            Chelsea Rousso, Nancy Kaplan Ostroff
# 11                                  Alan Northcott
#
#                      categories  \
# 0        [Business & Economics]
# 1                     [Fiction]
# 3                  [Psychology]
# 4                     [Medical]
# 5                     [Medical]
# 7                   [Computers]
# 8   [Biography & Autobiography]
# 9                     [Fiction]
# 10       [Business & Economics]
# 11       [Business & Economics]
#
#                                           description           isbn language  \
# 0   A revelatory exploration of the hottest trend ...  9780544002937       en
# 1   #1 New York Times Bestseller A Reese Witherspo...  9780735219113       en
# 3   Presents a controversial history of violence w...  9780143122012       en
# 4   Current Issues in Nursing provides a forum for...  9780323293198       en
# 5   Neonatal-perinatal medicine has a strong histo...  9780323326735       en
# 7   This book consists of 20 chapters in which the...  9783319107745       en
# 8   "The author's experience with grief after the ...  9781524732684       en
# 9   From the # 1 New York Times bestselling author...  9780698408326       en
# 10  Fashion Forward demystifies the exciting caree...  9781501328275       en
# 11  Money managers have traditionally used hedge f...  9781601380005       en
#
#                       publisher  \
# 0     Houghton Mifflin Harcourt
# 1                       Penguin
# 3             Penguin Group USA
# 4      Elsevier Health Sciences
# 5      Elsevier Health Sciences
# 7                      Springer
# 8                         Knopf
# 9                       Penguin
# 10    Bloomsbury Publishing USA
# 11  Atlantic Publishing Company
#
#                                                 title
# 0                                            Big Data
# 1                             Where the Crawdads Sing
# 3                     The Better Angels of Our Nature
# 4                  Current Issues In Nursing - E-Book
# 5   Current Controversies in Perinatology, An Issu...
# 7   New Trends in Computational Collective Intelli...
# 8                                            Option B
# 9                                       City of Girls
# 10                                    Fashion Forward
# 11                               The Hedge Funds Book

# %%
trending_books_data['categories'] = trending_books_data['categories'].apply(', '.join)

# %%
trending_books_data.head(10)
# Out:
#                                            authors                 categories  \
# 0         Viktor Mayer-Schönberger, Kenneth Cukier       Business & Economics
# 1                                      Delia Owens                    Fiction
# 3                                    Steven Pinker                 Psychology
# 4                 Perle Slavik Cowen, Sue Moorhead                    Medical
# 5                                   Robert H. Lane                    Medical
# 7   David Camacho, Sang-Wook Kim, Bogdan Trawiński                  Computers
# 8                   Sheryl Sandberg, Adam M. Grant  Biography & Autobiography
# 9                                Elizabeth Gilbert                    Fiction
# 10            Chelsea Rousso, Nancy Kaplan Ostroff       Business & Economics
# 11                                  Alan Northcott       Business & Economics
#
#                                           description           isbn language  \
# 0   A revelatory exploration of the hottest trend ...  9780544002937       en
# 1   #1 New York Times Bestseller A Reese Witherspo...  9780735219113       en
# 3   Presents a controversial history of violence w...  9780143122012       en
# 4   Current Issues in Nursing provides a forum for...  9780323293198       en
# 5   Neonatal-perinatal medicine has a strong histo...  9780323326735       en
# 7   This book consists of 20 chapters in which the...  9783319107745       en
# 8   "The author's experience with grief after the ...  9781524732684       en
# 9   From the # 1 New York Times bestselling author...  9780698408326       en
# 10  Fashion Forward demystifies the exciting caree...  9781501328275       en
# 11  Money managers have traditionally used hedge f...  9781601380005       en
#
#                       publisher  \
# 0     Houghton Mifflin Harcourt
# 1                       Penguin
# 3             Penguin Group USA
# 4      Elsevier Health Sciences
# 5      Elsevier Health Sciences
# 7                      Springer
# 8                         Knopf
# 9                       Penguin
# 10    Bloomsbury Publishing USA
# 11  Atlantic Publishing Company
#
#                                                 title
# 0                                            Big Data
# 1                             Where the Crawdads Sing
# 3                     The Better Angels of Our Nature
# 4                  Current Issues In Nursing - E-Book
# 5   Current Controversies in Perinatology, An Issu...
# 7   New Trends in Computational Collective Intelli...
# 8                                            Option B
# 9                                       City of Girls
# 10                                    Fashion Forward
# 11                               The Hedge Funds Book

# %%
trending_books_data.shape
# Out:
# (743, 7)

# %%
trending_books_data.to_pickle('trending_books_data.pkl')

# %%
trending_books_data.dtypes
# Out:
# authors        object
# categories     object
# description    object
# isbn           object
# language       object
# publisher      object
# title          object
# dtype: object

# %%
fulldata = pd.read_pickle('full_metadata.pkl')

# %%
fulldata.shape
# Out:
# (51487, 15)

# %%
fulldata.head(10)
# Out:
#             isbn   user_id          user_name  user_ratings  \
# 0  9780321948540    779608               Erin           4.0
# 1  9780321948540    753824       Rolf Häsänen           4.0
# 2  9780321948540  35798331             Valery           4.0
# 3  9780321948540   2100772              Bruce           1.0
# 4  9780321948540   1794100            Icepick           5.0
# 5  9780321948540   3425034                Deb           4.0
# 6  9780321948540  29448721               Mark           4.0
# 7  9780321948540  11916175     Angela Benthin           4.0
# 8  9780321948540   8176218  Cedric Jean-marie           0.0
# 9  9780321948540    289983            Candice           4.0
#
#                                     user_review_text      authors categories  \
# 0  There are a lot of great tips in this volume, ...  Scott Kelby  Computers
# 1  Not as many useful tips as volume1 unless you ...  Scott Kelby  Computers
# 2  Not as helpful as the first, but does go into ...  Scott Kelby  Computers
# 3  OMG. Surely the absolute worst, amature photo ...  Scott Kelby  Computers
# 4  The format may not be for everybody, but I rea...  Scott Kelby  Computers
# 5  Lots of great tips! This writer is engaging an...  Scott Kelby  Computers
# 6  For me it would have been a 3 because of secti...  Scott Kelby  Computers
# 7                                Very informational   Scott Kelby  Computers
# 8  I originally bought this trilogy for my wife w...  Scott Kelby  Computers
# 9  I'd actually give this 4.5 out of 5 stars for ...  Scott Kelby  Computers
#
#                                          description language  pageCount  \
# 0  Furnishes an overview of digital photography, ...       en      236.0
# 1  Furnishes an overview of digital photography, ...       en      236.0
# 2  Furnishes an overview of digital photography, ...       en      236.0
# 3  Furnishes an overview of digital photography, ...       en      236.0
# 4  Furnishes an overview of digital photography, ...       en      236.0
# 5  Furnishes an overview of digital photography, ...       en      236.0
# 6  Furnishes an overview of digital photography, ...       en      236.0
# 7  Furnishes an overview of digital photography, ...       en      236.0
# 8  Furnishes an overview of digital photography, ...       en      236.0
# 9  Furnishes an overview of digital photography, ...       en      236.0
#
#   printType  publishedYear          publisher                         title  \
# 0      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 1      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 2      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 3      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 4      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 5      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 6      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 7      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 8      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 9      BOOK         2013.0  Pearson Education  The Digital Photography Book
#
#    weighted_avg
# 0      4.128036
# 1      4.128036
# 2      4.128036
# 3      4.128036
# 4      4.128036
# 5      4.128036
# 6      4.128036
# 7      4.128036
# 8      4.128036
# 9      4.128036

# %%
fulldata.dtypes
# Out:
# isbn                 object
# user_id              object
# user_name            object
# user_ratings        float64
# user_review_text     object
# authors              object
# categories           object
# description          object
# language             object
# pageCount           float64
# printType            object
# publishedYear       float64
# publisher            object
# title                object
# weighted_avg        float64
# dtype: object

# %%
booksdata = fulldata[['authors','categories','description','isbn','language','publisher','title']]

# %%
booksdata.shape
# Out:
# (51487, 7)

# %%
booksdata.head()
# Out:
#        authors categories                                        description  \
# 0  Scott Kelby  Computers  Furnishes an overview of digital photography, ...
# 1  Scott Kelby  Computers  Furnishes an overview of digital photography, ...
# 2  Scott Kelby  Computers  Furnishes an overview of digital photography, ...
# 3  Scott Kelby  Computers  Furnishes an overview of digital photography, ...
# 4  Scott Kelby  Computers  Furnishes an overview of digital photography, ...
#
#             isbn language          publisher                         title
# 0  9780321948540       en  Pearson Education  The Digital Photography Book
# 1  9780321948540       en  Pearson Education  The Digital Photography Book
# 2  9780321948540       en  Pearson Education  The Digital Photography Book
# 3  9780321948540       en  Pearson Education  The Digital Photography Book
# 4  9780321948540       en  Pearson Education  The Digital Photography Book

# %%
booksdata.drop_duplicates(inplace=True)
# Out:
# /Users/sameerdeekshit/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
booksdata.shape
# Out:
# (2279, 7)

# %%
booksdata.head(10)
# Out:
#                 authors   categories  \
# 0           Scott Kelby    Computers
# 30          Scott Kelby  Photography
# 60          Scott Kelby    Computers
# 90         Susan Sontag  Photography
# 169         Scott Kelby  Photography
# 246         Scott Kelby  Photography
# 276           Liz Wells  Photography
# 306     Michael Freeman  Photography
# 343  Edward M. Robinson          Law
# 373         Scott Kelby  Photography
#
#                                            description           isbn  \
# 0    Furnishes an overview of digital photography, ...  9780321948540
# 30   Scott Kelby, author of the top-selling digital...  9780133856934
# 60   Offers advice for shooting different types of ...  9780133856880
# 90   Winner of the National Book Critics' Circle Aw...  9781429957113
# 169  What could top the #1 best-selling photography...  9780134385273
# 246  Scott Kelby, author of The Digital Photography...  9780133510720
# 276  This seminal text for photography students ide...  9780415307031
# 306  Completely updated and revised to reflect tech...  9781579907594
# 343  Crime Scene Photography is a book wrought from...  9780080476926
# 373  Includes: The Digital Photography Book The Dig...  9780321686008
#
#     language                  publisher  \
# 0         en          Pearson Education
# 30        en             Peachpit Press
# 60        en          Pearson Education
# 90        en  Farrar, Straus and Giroux
# 169       en             Peachpit Press
# 246       en             Peachpit Press
# 276       en           Psychology Press
# 306       en                 Lark Books
# 343       en                   Elsevier
# 373       en          Pearson Education
#
#                                                  title
# 0                         The Digital Photography Book
# 30                The Digital Photography Book, Part 5
# 60                        The Digital Photography Book
# 90                                      On Photography
# 169    The Best of The Digital Photography Book Series
# 246                       The Digital Photography Book
# 276                                        Photography
# 306          The Complete Guide to Digital Photography
# 343                            Crime Scene Photography
# 373  Scott Kelby's Digital Photography Books, Volum...

# %%
booksdata_trendingdata_combined = pd.concat([booksdata,trending_books_data])

# %%
booksdata_trendingdata_combined.shape
# Out:
# (3022, 7)

# %%
booksdata_trendingdata_combined.head()
# Out:
#           authors   categories  \
# 0     Scott Kelby    Computers
# 30    Scott Kelby  Photography
# 60    Scott Kelby    Computers
# 90   Susan Sontag  Photography
# 169   Scott Kelby  Photography
#
#                                            description           isbn  \
# 0    Furnishes an overview of digital photography, ...  9780321948540
# 30   Scott Kelby, author of the top-selling digital...  9780133856934
# 60   Offers advice for shooting different types of ...  9780133856880
# 90   Winner of the National Book Critics' Circle Aw...  9781429957113
# 169  What could top the #1 best-selling photography...  9780134385273
#
#     language                  publisher  \
# 0         en          Pearson Education
# 30        en             Peachpit Press
# 60        en          Pearson Education
# 90        en  Farrar, Straus and Giroux
# 169       en             Peachpit Press
#
#                                                title
# 0                       The Digital Photography Book
# 30              The Digital Photography Book, Part 5
# 60                      The Digital Photography Book
# 90                                    On Photography
# 169  The Best of The Digital Photography Book Series

# %%
booksdata_trendingdata_combined.drop_duplicates(inplace=True)

# %%
booksdata_trendingdata_combined.shape
# Out:
# (2905, 7)

# %%
#Get list of all isbns
fullisbns = booksdata_trendingdata_combined[['isbn']]

# %%
fullisbns.drop_duplicates(inplace=True)
fullisbns.head()
# Out:
# /Users/sameerdeekshit/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#               isbn
# 0    9780321948540
# 30   9780133856934
# 60   9780133856880
# 90   9781429957113
# 169  9780134385273

# %%
fullisbns_list = fullisbns['isbn'].tolist()

# %%
fullisbnsfile = open("all_isbn_list.pkl","wb")
pickle.dump(fullisbns_list,fullisbnsfile)
fullisbnsfile.close()

# %%
#Get list of all isbns
trendingisbns = trending_books_data[['isbn']]

# %%
trendingisbns.drop_duplicates(inplace=True)
trendingisbns_list = trendingisbns['isbn'].tolist()
trendingisbnsfile = open("all_isbn_list.pkl","wb")
pickle.dump(trendingisbns_list,trendingisbnsfile)
trendingisbnsfile.close()
# Out:
# /Users/sameerdeekshit/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#Get list of all isbns and book titles
combined_isbn_title_df = booksdata_trendingdata_combined[['isbn','title']]

# %%
combined_isbn_title_df.drop_duplicates(inplace=True)
# Out:
# /Users/sameerdeekshit/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
combined_isbn_title_df.head()
# Out:
#               isbn                                            title
# 0    9780321948540                     The Digital Photography Book
# 30   9780133856934             The Digital Photography Book, Part 5
# 60   9780133856880                     The Digital Photography Book
# 90   9781429957113                                   On Photography
# 169  9780134385273  The Best of The Digital Photography Book Series

# %%
combined_isbn_title_dict = pd.Series(combined_isbn_title_df.title.values,index=combined_isbn_title_df.isbn).to_dict()

# %%
combinedisbntitlefile = open("combined_isbn_title_dict.pkl","wb")
pickle.dump(combined_isbn_title_dict,combinedisbntitlefile)
combinedisbntitlefile.close()

# %%
booksdata_trendingdata_combined.to_pickle('booksdata_trendingdata_combined.pkl')

# %%
combineddata = pd.read_pickle('booksdata_trendingdata_combined.pkl')

# %%
combineddata.shape
# Out:
# (2905, 7)

# %%
combineddata.head()
# Out:
#           authors   categories  \
# 0     Scott Kelby    Computers
# 30    Scott Kelby  Photography
# 60    Scott Kelby    Computers
# 90   Susan Sontag  Photography
# 169   Scott Kelby  Photography
#
#                                            description           isbn  \
# 0    Furnishes an overview of digital photography, ...  9780321948540
# 30   Scott Kelby, author of the top-selling digital...  9780133856934
# 60   Offers advice for shooting different types of ...  9780133856880
# 90   Winner of the National Book Critics' Circle Aw...  9781429957113
# 169  What could top the #1 best-selling photography...  9780134385273
#
#     language                  publisher  \
# 0         en          Pearson Education
# 30        en             Peachpit Press
# 60        en          Pearson Education
# 90        en  Farrar, Straus and Giroux
# 169       en             Peachpit Press
#
#                                                title
# 0                       The Digital Photography Book
# 30              The Digital Photography Book, Part 5
# 60                      The Digital Photography Book
# 90                                    On Photography
# 169  The Best of The Digital Photography Book Series

# %%
combineddata.reset_index(drop=True,inplace=True)

# %%
combineddata.head()
# Out:
#         authors   categories  \
# 0   Scott Kelby    Computers
# 1   Scott Kelby  Photography
# 2   Scott Kelby    Computers
# 3  Susan Sontag  Photography
# 4   Scott Kelby  Photography
#
#                                          description           isbn language  \
# 0  Furnishes an overview of digital photography, ...  9780321948540       en
# 1  Scott Kelby, author of the top-selling digital...  9780133856934       en
# 2  Offers advice for shooting different types of ...  9780133856880       en
# 3  Winner of the National Book Critics' Circle Aw...  9781429957113       en
# 4  What could top the #1 best-selling photography...  9780134385273       en
#
#                    publisher                                            title
# 0          Pearson Education                     The Digital Photography Book
# 1             Peachpit Press             The Digital Photography Book, Part 5
# 2          Pearson Education                     The Digital Photography Book
# 3  Farrar, Straus and Giroux                                   On Photography
# 4             Peachpit Press  The Best of The Digital Photography Book Series

# %%
fulldata = pd.read_pickle('full_metadata.pkl')

# %%
fulldata.shape
# Out:
# (51487, 15)

# %%
fulldata.head()
# Out:
#             isbn   user_id     user_name  user_ratings  \
# 0  9780321948540    779608          Erin           4.0
# 1  9780321948540    753824  Rolf Häsänen           4.0
# 2  9780321948540  35798331        Valery           4.0
# 3  9780321948540   2100772         Bruce           1.0
# 4  9780321948540   1794100       Icepick           5.0
#
#                                     user_review_text      authors categories  \
# 0  There are a lot of great tips in this volume, ...  Scott Kelby  Computers
# 1  Not as many useful tips as volume1 unless you ...  Scott Kelby  Computers
# 2  Not as helpful as the first, but does go into ...  Scott Kelby  Computers
# 3  OMG. Surely the absolute worst, amature photo ...  Scott Kelby  Computers
# 4  The format may not be for everybody, but I rea...  Scott Kelby  Computers
#
#                                          description language  pageCount  \
# 0  Furnishes an overview of digital photography, ...       en      236.0
# 1  Furnishes an overview of digital photography, ...       en      236.0
# 2  Furnishes an overview of digital photography, ...       en      236.0
# 3  Furnishes an overview of digital photography, ...       en      236.0
# 4  Furnishes an overview of digital photography, ...       en      236.0
#
#   printType  publishedYear          publisher                         title  \
# 0      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 1      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 2      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 3      BOOK         2013.0  Pearson Education  The Digital Photography Book
# 4      BOOK         2013.0  Pearson Education  The Digital Photography Book
#
#    weighted_avg
# 0      4.128036
# 1      4.128036
# 2      4.128036
# 3      4.128036
# 4      4.128036

# %%
tfidfv = TfidfVectorizer(analyzer='word',stop_words=set(stopwords.words('english')))

# %%
vocab = tfidfv.fit_transform(combineddata['description'])
similarity = linear_kernel(vocab, vocab)
isbns = pd.Series(combineddata['isbn']).to_dict()
isbns = dict((v,k) for k,v in isbns.items())

# %%
def trending_similar(isbn):
    bookid = isbns[isbn]
    bookslist = list(enumerate(similarity[bookid]))
    bookslist.sort(key=lambda x: x[1], reverse=True)
    top10TrendingBooks = bookslist[1:11]
    return top10TrendingBooks

# %%
isbn_userid = fulldata[['isbn','user_id']]

# %%
isbn_userid.shape
# Out:
# (51487, 2)

# %%
isbn_userid.head()
# Out:
#             isbn   user_id
# 0  9780321948540    779608
# 1  9780321948540    753824
# 2  9780321948540  35798331
# 3  9780321948540   2100772
# 4  9780321948540   1794100

# %%
user_books_read_mapping = {}
for index, row in isbn_userid.iterrows():
    isbn = row['isbn']
    userid = row['user_id']
    if userid in user_books_read_mapping.keys():
        user_books_read_mapping[userid].append(isbn)
    else:
        bookslist = []
        user_books_read_mapping[userid] = bookslist
        user_books_read_mapping[userid].append(isbn)

# %%
user_books_sorted = sorted(user_books_read_mapping.items(), key=lambda x : len(x[1]), reverse= True)

# %%
user_books_sorted_json = {}
for i in user_books_sorted:
    user_books_sorted_json[str(i[0])] = i[1]

ubfile = open("user_books_sorted.pkl","wb")
pickle.dump(user_books_sorted_json,ubfile)
ubfile.close()

# %%
usersbooks = pickle.load(open( "user_books_sorted.pkl", "rb" ) )

# %%
isbnlookup = dict((v,k) for k,v in isbns.items())

# %%
def trendingTop10(user):
    booklist = usersbooks[user]
    ratingsbooks = []
    recommendedbooks = []
    for book in booklist:
        newbooks = trending_similar(book)
        ratingsbooks = ratingsbooks + newbooks
    ratingsbooks = list(set(ratingsbooks))
    for item in ratingsbooks:
        try :
            bookisbn = isbnlookup[item[0]]
            if bookisbn in trendingisbns_list:
                recommendedbooks.append([item[1],bookisbn])
        except:
            continue
    recommendedbooks.sort(key=lambda x: x[1], reverse=True)
    return recommendedbooks[:10]

# %%
#get isbn from recommended ratings
def top10isbn(recommendations):
    top10_isbn = []
    for item in recommendations:
        item_isbn = item[1]
        top10_isbn.append(item_isbn)
    return top10_isbn

# %%
trendingrecommended = trendingTop10('269235')
isbn_recommendations = top10isbn(trendingrecommended)
print("Recommendations based on trending books : ")
for isbnitem in isbn_recommendations :
    print("ISBN :", str(isbnitem), "Title :", str(combined_isbn_title_dict[isbnitem]))
    #print("ISBN :", str(isbnitem))
# Out:
# Recommendations based on trending books :
# ISBN : 9788186775097 Title : The Five Love Languages
# ISBN : 9788175110625 Title : Answer is Blowing in the Wind
# ISBN : 9788175110625 Title : Answer is Blowing in the Wind
# ISBN : 9783319326931 Title : Human Dignity of the Vulnerable in the Age of Rights
# ISBN : 9783319326931 Title : Human Dignity of the Vulnerable in the Age of Rights
# ISBN : 9783319012223 Title : Most-Cited Scholars in Criminology and Criminal Justice, 1986-2010
# ISBN : 9781948584081 Title : The Catalain Book of Secrets
# ISBN : 9781943562183 Title : Rescuing Wendy
# ISBN : 9781943562183 Title : Rescuing Wendy
# ISBN : 9781895431162 Title : New World Order & Third World
